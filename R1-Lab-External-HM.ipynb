# %% [markdown]
# # External Lab

# %% [markdown]
# # Part-1

# %% [markdown]
# ## About the dataset
#
# This is perhaps the best known database to be found in the pattern recognition literature. The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.  One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
# Attribute Information:
#    1. sepal length in cm
#    2. sepal width in cm
#    3. petal length in cm
#    4. petal width in cm
#    5. class:
#       -- Iris Setosa
#       -- Iris Versicolour
#       -- Iris Virginica

# %% [markdown]
# ### Read the dataset and store it in the dataframe named Iris

# %%
import numpy as np
import pandas as pd
S1 = pd.read_csv('Iris.csv')
Iris=pd.DataFrame(S1)
Iris
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                     5.1                  3.5                   1.4
# 1                     4.9                  3.0                   1.4
# 2                     4.7                  3.2                   1.3
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# 5                     5.4                  3.9                   1.7
# 6                     4.6                  3.4                   1.4
# 7                     5.0                  3.4                   1.5
# 8                     4.4                  2.9                   1.4
# 9                     4.9                  3.1                   1.5
# 10                    5.4                  3.7                   1.5
# 11                    4.8                  3.4                   1.6
# 12                    4.8                  3.0                   1.4
# ...

# %% [markdown]
# ### Find out the datatypes of each and every column

# %%
Iris.dtypes
# Out:
# Sepal Length (in cm)    float64
# Sepal Width in (cm)     float64
# Petal length (in cm)    float64
# Petal width (in cm)     float64
# Class                    object
# dtype: object

# %% [markdown]
# ### Print top 10 & bottom 10 samples from the dataframe

# %%
Iris.head(10)
Iris.tail(10)
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 140                   6.7                  3.1                   5.6
# 141                   6.9                  3.1                   5.1
# 142                   5.8                  2.7                   5.1
# 143                   6.8                  3.2                   5.9
# 144                   6.7                  3.3                   5.7
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 140                  2.4  Iris-virginica
# 141                  2.3  Iris-virginica
# 142                  1.9  Iris-virginica
# ...

# %% [markdown]
# ### Find the shape of the dataset

# %%
Iris.shape
# Out:
# (150, 5)

# %% [markdown]
# ### Set the index of the dataframe to be the first column

# %%
Iris.set_index('Sepal Length (in cm)')
# Out:
#                       Sepal Width in (cm)  Petal length (in cm)  \
# Sepal Length (in cm)
# 5.1                                   3.5                   1.4
# 4.9                                   3.0                   1.4
# 4.7                                   3.2                   1.3
# 4.6                                   3.1                   1.5
# 5.0                                   3.6                   1.4
# 5.4                                   3.9                   1.7
# 4.6                                   3.4                   1.4
# 5.0                                   3.4                   1.5
# 4.4                                   2.9                   1.4
# 4.9                                   3.1                   1.5
# 5.4                                   3.7                   1.5
# 4.8                                   3.4                   1.6
# 4.8                                   3.0                   1.4
# ...

# %% [markdown]
# ### Use iloc function to print all the rows of the 3rd column

# %%
Iris.iloc[0:150,2]
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
# 5      1.7
# 6      1.4
# 7      1.5
# 8      1.4
# 9      1.5
# 10     1.5
# 11     1.6
# 12     1.4
# 13     1.1
# 14     1.2
# 15     1.5
# 16     1.3
# 17     1.4
# 18     1.7
# 19     1.5
# 20     1.7
# 21     1.5
# 22     1.0
# 23     1.7
# 24     1.9
# 25     1.6
# 26     1.6
# 27     1.5
# 28     1.4
# 29     1.6
#       ...
# 120    5.7
# 121    4.9
# 122    6.7
# 123    4.9
# 124    5.7
# 125    6.0
# 126    4.8
# 127    4.9
# 128    5.6
# 129    5.8
# 130    6.1
# 131    6.4
# 132    5.6
# 133    5.1
# 134    5.6
# 135    6.1
# 136    5.6
# 137    5.5
# 138    4.8
# 139    5.4
# 140    5.6
# 141    5.1
# 142    5.1
# 143    5.9
# 144    5.7
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: Petal length (in cm), Length: 150, dtype: float64

# %% [markdown]
# ### Slicing
# Print only the Sepal width and Sepal Length for first 10 rows

# %%
print (Iris[['Sepal Width in (cm)', 'Sepal Length (in cm)']].head(10))
# Out:
#    Sepal Width in (cm)  Sepal Length (in cm)
# 0                  3.5                   5.1
# 1                  3.0                   4.9
# 2                  3.2                   4.7
# 3                  3.1                   4.6
# 4                  3.6                   5.0
# 5                  3.9                   5.4
# 6                  3.4                   4.6
# 7                  3.4                   5.0
# 8                  2.9                   4.4
# 9                  3.1                   4.9

# %% [markdown]
# ### Using Logical statements for indexing
# Print all the columns of row which has class name "Iris-setosa"

# %%
Iris[Iris['Class']=='Iris-setosa']
# Out:
#     Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                    5.1                  3.5                   1.4
# 1                    4.9                  3.0                   1.4
# 2                    4.7                  3.2                   1.3
# 3                    4.6                  3.1                   1.5
# 4                    5.0                  3.6                   1.4
# 5                    5.4                  3.9                   1.7
# 6                    4.6                  3.4                   1.4
# 7                    5.0                  3.4                   1.5
# 8                    4.4                  2.9                   1.4
# 9                    4.9                  3.1                   1.5
# 10                   5.4                  3.7                   1.5
# 11                   4.8                  3.4                   1.6
# 12                   4.8                  3.0                   1.4
# ...

# %% [markdown]
# ### Multiply Sepal Length and width and store it under the column name "SepalExtra" in the same Iris dataframe

# %%
Iris['SepalExtra'] = Iris['Sepal Length (in cm)'] * Iris['Sepal Width in (cm)']
Iris
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                     5.1                  3.5                   1.4
# 1                     4.9                  3.0                   1.4
# 2                     4.7                  3.2                   1.3
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# 5                     5.4                  3.9                   1.7
# 6                     4.6                  3.4                   1.4
# 7                     5.0                  3.4                   1.5
# 8                     4.4                  2.9                   1.4
# 9                     4.9                  3.1                   1.5
# 10                    5.4                  3.7                   1.5
# 11                    4.8                  3.4                   1.6
# 12                    4.8                  3.0                   1.4
# ...

# %% [markdown]
# ### Find out the mean and variance for each column but for class column

# %%
import matplotlib.pyplot as plt
print ('# Mean of Iris-setosa')
print(np.mean(Iris[Iris['Class']=='Iris-setosa']))
print ('# Mean of Iris-versicolor')
print(np.mean(Iris[Iris['Class']=='Iris-versicolor']))
print ('# Mean of Iris-virginica')
print(np.mean(Iris[Iris['Class']=='Iris-virginica']))
print ('# variance of Iris-setosa')
print(np.var(Iris[Iris['Class']=='Iris-setosa']))
print ('# variance of Iris-versicolor')
print(np.var(Iris[Iris['Class']=='Iris-versicolor']))
print ('# variance of Iris-virginica')
print(np.var(Iris[Iris['Class']=='Iris-virginica']))
# Out:
# # Mean of Iris-setosa
# Sepal Length (in cm)     5.0060
# Sepal Width in (cm)      3.4180
# Petal length (in cm)     1.4640
# Petal width (in cm)      0.2440
# SepalExtra              17.2088
# dtype: float64
# # Mean of Iris-versicolor
# Sepal Length (in cm)     5.9360
# Sepal Width in (cm)      2.7700
# Petal length (in cm)     4.2600
# Petal width (in cm)      1.3260
# SepalExtra              16.5262
# dtype: float64
# # Mean of Iris-virginica
# Sepal Length (in cm)     6.5880
# Sepal Width in (cm)      2.9740
# Petal length (in cm)     5.5520
# Petal width (in cm)      2.0260
# SepalExtra              19.6846
# dtype: float64
# # variance of Iris-setosa
# Sepal Length (in cm)    0.121764
# Sepal Width in (cm)     0.142276
# Petal length (in cm)    0.029504
# Petal width (in cm)     0.011264
# SepalExtra              8.515087
# dtype: float64
# # variance of Iris-versicolor
# Sepal Length (in cm)    0.261104
# Sepal Width in (cm)     0.096500
# Petal length (in cm)    0.216400
# ...

# %% [markdown]
# ### Write a function that accepts two numbers as input and prints them - Pass the Sepal length and sepal width of 5th row and print the output

# %% [markdown]
# ### Find the range of all the columns in the dataset
#
# *Range = Max value - Min value (in the column)*

# %%
range_sepal_length = max(Iris['Sepal Length (in cm)']) - min(Iris['Sepal Length (in cm)'])
# range of Sepal Length in (cm)
print (range_sepal_length)
range_sepal_width = max(Iris['Sepal Width in (cm)']) - min(Iris['Sepal Width in (cm)'])
# range of Sepal Width in (cm)
print (range_sepal_width)
range_petal_lentgh =  max(Iris['Petal length (in cm)']) - min(Iris['Petal length (in cm)'])
# range of Petal length (in cm)
print(range_petal_lentgh)
range_petal_width = max(Iris['Petal width (in cm)']) - min(Iris['Petal width (in cm)'])
# range of Petal width (in cm)
print(range_petal_width)
# Out:
# 3.6000000000000005
# 2.4000000000000004
# 5.9
# 2.4

# %% [markdown]
# ### Sort the entire dataset according to the column Petal width

# %%
result = Iris.sort_values('Petal width (in cm)')
result
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 32                    5.2                  4.1                   1.5
# 13                    4.3                  3.0                   1.1
# 37                    4.9                  3.1                   1.5
# 9                     4.9                  3.1                   1.5
# 12                    4.8                  3.0                   1.4
# 34                    4.9                  3.1                   1.5
# 0                     5.1                  3.5                   1.4
# 27                    5.2                  3.5                   1.5
# 28                    5.2                  3.4                   1.4
# 29                    4.7                  3.2                   1.6
# 30                    4.8                  3.1                   1.6
# 33                    5.5                  4.2                   1.4
# 36                    5.5                  3.5                   1.3
# ...

# %% [markdown]
# ### Remove the new column "SepalExtra" from the dataframe

# %%
Iris['SepalExtra'] = Iris['Sepal Length (in cm)'] * Iris['Sepal Width in (cm)']
Iris = Iris.drop(['SepalExtra'], axis = 1)
Iris
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                     5.1                  3.5                   1.4
# 1                     4.9                  3.0                   1.4
# 2                     4.7                  3.2                   1.3
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# 5                     5.4                  3.9                   1.7
# 6                     4.6                  3.4                   1.4
# 7                     5.0                  3.4                   1.5
# 8                     4.4                  2.9                   1.4
# 9                     4.9                  3.1                   1.5
# 10                    5.4                  3.7                   1.5
# 11                    4.8                  3.4                   1.6
# 12                    4.8                  3.0                   1.4
# ...

# %% [markdown]
# ### Take only the top 10 rows of the dataset with only first 3 columns and store it in a dataframe named "IrisSubset"

# %%
IrisSubset = Iris.drop(['Petal width (in cm)', 'Class'], axis = 1).head(10)
IrisSubset
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
# 8                   4.4                  2.9                   1.4
# 9                   4.9                  3.1                   1.5

# %% [markdown]
# # Part-2

# %% [markdown]
# ## The dataset HR contains information collected from the survey floated by a HR within the company.
#
#
# As a part of this lab, you are expected to answer the below questions

# %% [markdown]
# ### Import numpy and Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Import the dataset (Note: The dataset is in .txt format) - Make sure to use delimiters

# %%
#HR = open('HR.txt','r')
#HR = pd.read_csv("HR.txt")
HR = open('HR.txt','r')
lines = HR.read().split("\n")
# define length of columns
Individual  = ["" for x in range(len(lines))]
Attrition = ["" for x in range(len(lines))]
Age = ["" for x in range(len(lines))]
BusinessTravel = ["" for x in range(len(lines))]
DailyRate = ["" for x in range(len(lines))]
Department = ["" for x in range(len(lines))]
DistanceFromHome = ["" for x in range(len(lines))]
Education = ["" for x in range(len(lines))]
EducationField = ["" for x in range(len(lines))]
EmployeeCount = ["" for x in range(len(lines))]
EmployeeNumber = ["" for x in range(len(lines))]
EnvironmentSatisfaction = ["" for x in range(len(lines))]
Gender = ["" for x in range(len(lines))]
HourlyRate = ["" for x in range(len(lines))]
JobInvolvement = ["" for x in range(len(lines))]
JobLevel = ["" for x in range(len(lines))]
JobRole = ["" for x in range(len(lines))]
JobSatisfaction = ["" for x in range(len(lines))]
MaritalStatus = ["" for x in range(len(lines))]
MonthlyIncome = ["" for x in range(len(lines))]
MonthlyRate = ["" for x in range(len(lines))]
NumCompaniesWorked = ["" for x in range(len(lines))]
OverTime = ["" for x in range(len(lines))]
PercentSalaryHike = ["" for x in range(len(lines))]
PerformanceRating = ["" for x in range(len(lines))]
RelationshipSatisfaction = ["" for x in range(len(lines))]
StandardHours = ["" for x in range(len(lines))]
StockOptionLevel = ["" for x in range(len(lines))]
TotalWorkingYears = ["" for x in range(len(lines))]
TrainingTimesLastYear = ["" for x in range(len(lines))]
WorkLifeBalance = ["" for x in range(len(lines))]
YearsAtCompany = ["" for x in range(len(lines))]
YearsInCurrentRole = ["" for x in range(len(lines))]
YearsSinceLastPromotion = ["" for x in range(len(lines))]
YearsWithCurrManager = ["" for x in range(len(lines))]
i=0
for l in lines:
    values = l.split("\t")
    Individual [i]=values[0]
    Attrition [i]=values[1]
    Age[i]=values[2]
    BusinessTravel[i]=values[3]
    DailyRate[i]=values[4]
    Department[i]=values[5]
    DistanceFromHome[i]=values[6]
    Education[i]=values[7]
    EducationField[i]=values[8]
    EmployeeCount[i]=values[9]
    EmployeeNumber[i]=values[10]
    EnvironmentSatisfaction[i]=values[11]
    Gender[i]=values[12]
    HourlyRate[i]=values[13]
    JobInvolvement[i]=values[14]
    JobLevel[i]=values[15]
    JobRole[i]=values[16]
    JobSatisfaction[i]=values[17]
    MaritalStatus[i]=values[18]
    MonthlyIncome[i]=values[19]
    MonthlyRate[i]=values[20]
    NumCompaniesWorked[i]=values[21]
    OverTime[i]=values[22]
    PercentSalaryHike[i]=values[23]
    PerformanceRating[i]=values[24]
    RelationshipSatisfaction[i]=values[25]
    StandardHours[i]=values[26]
    StockOptionLevel[i]=values[27]
    TotalWorkingYears[i]=values[28]
    TrainingTimesLastYear[i]=values[29]
    WorkLifeBalance[i]=values[30]
    YearsAtCompany[i]=values[31]
    YearsInCurrentRole[i]=values[32]
    YearsSinceLastPromotion[i]=values[33]
    YearsWithCurrManager[i]=values[34]
    print(Individual [i], Attrition[i],Age[i],BusinessTravel[i],DailyRate[i],Department[i],
DistanceFromHome[i],
Education[i],
EducationField[i],
EmployeeCount[i],
EmployeeNumber[i],
EnvironmentSatisfaction[i],
Gender[i],
HourlyRate[i],
JobInvolvement[i],
JobLevel[i],
JobRole[i],
JobSatisfaction[i],
MaritalStatus[i],
MonthlyIncome[i],
MonthlyRate[i],
NumCompaniesWorked[i],
OverTime[i],
PercentSalaryHike[i],
PerformanceRating[i],
RelationshipSatisfaction[i],
StandardHours[i],
StockOptionLevel[i],
TotalWorkingYears[i],
TrainingTimesLastYear[i],
WorkLifeBalance[i],
YearsAtCompany[i],
YearsInCurrentRole[i],
YearsSinceLastPromotion[i],
YearsWithCurrManager[i])
    i=i+1
# Out:
# Individual  Attrition Age BusinessTravel DailyRate Department DistanceFromHome Education EducationField EmployeeCount EmployeeNumber EnvironmentSatisfaction Gender HourlyRate JobInvolvement JobLevel JobRole JobSatisfaction MaritalStatus MonthlyIncome MonthlyRate NumCompaniesWorked OverTime PercentSalaryHike PerformanceRating RelationshipSatisfaction StandardHours StockOptionLevel TotalWorkingYears TrainingTimesLastYear WorkLifeBalance YearsAtCompany YearsInCurrentRole YearsSinceLastPromotion YearsWithCurrManager
# Ind1 Yes 41 1 1102 1 1 2 1 1 1 2 2 94 3 2 1 4 1 5993 19479 8 1 11 3 1 80 0 8 0 1 6 4 0 5
# Ind2 No 49 2 279 2 8 1 1 1 2 3 1 61 2 2 2 2 2 5130 24907 1 2 23 4 4 80 1 10 3 3 10 7 1 7
# Ind3 Yes 37 1 1373 2 2 2 6 1 4 4 1 92 2 1 3 3 1 2090 2396 6 1 15 3 2 80 0 7 3 3 0 0 0 0
# Ind4 No 33 2 1392 2 3 4 1 1 5 4 2 56 3 1 2 3 2 2909 23159 1 1 11 3 3 80 0 8 3 3 8 7 3 0
# Ind5 No 27 1 591 2 2 1 2 1 7 1 1 40 3 1 3 2 2 3468 16632 9 2 12 3 4 80 1 6 3 3 2 2 2 2
# ...

# %% [markdown]
# ### Print the no of rows and columns in the dataset

# %%
#HR = open('HR.txt','r')
#HR = pd.read_csv("HR.txt")
HR = open('HR.txt','r')
lines = HR.read().split("\n")
i=0
for l in lines:
    values = l.split("\t")
    Individual [i]=values[0]
    Attrition [i]=values[1]
    Age[i]=values[2]
    BusinessTravel[i]=values[3]
    DailyRate[i]=values[4]
    Department[i]=values[5]
    DistanceFromHome[i]=values[6]
    Education[i]=values[7]
    EducationField[i]=values[8]
    EmployeeCount[i]=values[9]
    EmployeeNumber[i]=values[10]
    EnvironmentSatisfaction[i]=values[11]
    Gender[i]=values[12]
    HourlyRate[i]=values[13]
    JobInvolvement[i]=values[14]
    JobLevel[i]=values[15]
    JobRole[i]=values[16]
    JobSatisfaction[i]=values[17]
    MaritalStatus[i]=values[18]
    MonthlyIncome[i]=values[19]
    MonthlyRate[i]=values[20]
    NumCompaniesWorked[i]=values[21]
    OverTime[i]=values[22]
    PercentSalaryHike[i]=values[23]
    PerformanceRating[i]=values[24]
    RelationshipSatisfaction[i]=values[25]
    StandardHours[i]=values[26]
    StockOptionLevel[i]=values[27]
    TotalWorkingYears[i]=values[28]
    TrainingTimesLastYear[i]=values[29]
    WorkLifeBalance[i]=values[30]
    YearsAtCompany[i]=values[31]
    YearsInCurrentRole[i]=values[32]
    YearsSinceLastPromotion[i]=values[33]
    YearsWithCurrManager[i]=values[34]
    print(Individual [i], Attrition[i],Age[i],BusinessTravel[i],DailyRate[i],Department[i],
DistanceFromHome[i],
Education[i],
EducationField[i],
EmployeeCount[i],
EmployeeNumber[i],
EnvironmentSatisfaction[i],
Gender[i],
HourlyRate[i],
JobInvolvement[i],
JobLevel[i],
JobRole[i],
JobSatisfaction[i],
MaritalStatus[i],
MonthlyIncome[i],
MonthlyRate[i],
NumCompaniesWorked[i],
OverTime[i],
PercentSalaryHike[i],
PerformanceRating[i],
RelationshipSatisfaction[i],
StandardHours[i],
StockOptionLevel[i],
TotalWorkingYears[i],
TrainingTimesLastYear[i],
WorkLifeBalance[i],
YearsAtCompany[i],
YearsInCurrentRole[i],
YearsSinceLastPromotion[i],
YearsWithCurrManager[i])
    i=i+1

# %% [markdown]
# ### Find out the type of each and every column in the dataset

# %%
# Create Data frame
df ={ 'Individual ':Individual,
    'Attrition':Attrition,
    'Age':Age,
    'BusinessTravel':BusinessTravel,
    'DailyRate':DailyRate,
    'Department':Department,
    'DistanceFromHome':DistanceFromHome,
    'Education':Education,
    'EducationField':EducationField,
    'EmployeeCount':EmployeeCount,
    'EmployeeNumber':EmployeeNumber,
    'EnvironmentSatisfaction':EnvironmentSatisfaction,
    'Gender':Gender,
    'HourlyRate':HourlyRate,
    'JobInvolvement':JobInvolvement,
    'JobLevel':JobLevel,
    'JobRole':JobRole,
    'JobSatisfaction':JobSatisfaction,
    'MaritalStatus':MaritalStatus,
    'MonthlyIncome':MonthlyIncome,
    'MonthlyRate':MonthlyRate,
    'NumCompaniesWorked':NumCompaniesWorked,
    'OverTime':OverTime,
    'PercentSalaryHike':PercentSalaryHike,
    'PerformanceRating':PerformanceRating,
    'RelationshipSatisfaction':RelationshipSatisfaction,
    'StandardHours':StandardHours,
    'StockOptionLevel':StockOptionLevel,
    'TotalWorkingYears':TotalWorkingYears,
    'TrainingTimesLastYear':TrainingTimesLastYear,
    'WorkLifeBalance':WorkLifeBalance,
    'YearsAtCompany':YearsAtCompany,
    'YearsInCurrentRole':YearsInCurrentRole,
    'YearsSinceLastPromotion':YearsSinceLastPromotion,
    'YearsWithCurrManager':YearsWithCurrManager,
     }
df= pd.DataFrame(df)
df.dtypes
# Out:
# Individual                  object
# Attrition                   object
# Age                         object
# BusinessTravel              object
# DailyRate                   object
# Department                  object
# DistanceFromHome            object
# Education                   object
# EducationField              object
# EmployeeCount               object
# EmployeeNumber              object
# EnvironmentSatisfaction     object
# Gender                      object
# HourlyRate                  object
# JobInvolvement              object
# JobLevel                    object
# JobRole                     object
# JobSatisfaction             object
# MaritalStatus               object
# MonthlyIncome               object
# MonthlyRate                 object
# NumCompaniesWorked          object
# OverTime                    object
# PercentSalaryHike           object
# PerformanceRating           object
# RelationshipSatisfaction    object
# StandardHours               object
# ...

# %% [markdown]
# ### Print out all the rows from 3rd column to 10th columns

# %%
df.iloc[0:1470,2:10]
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0     Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education
# 1      41               1       1102           1                 1          2
# 2      49               2        279           2                 8          1
# 3      37               1       1373           2                 2          2
# 4      33               2       1392           2                 3          4
# 5      27               1        591           2                 2          1
# 6      32               2       1005           2                 2          2
# 7      59               1       1324           2                 3          3
# 8      30               1       1358           2                24          1
# 9      38               2        216           2                23          3
# 10     36               1       1299           2                27          3
# ...

# %% [markdown]
# ### Find out the no of male & female employees in the company
#
# *Hint: Use can use a condition to find out the no of 1s and 0s in gender and sum it*

# %%
# Count for male
df1 = df[df['Gender']=='1']
cnt_male = df1.count
print(cnt_male)
#Count for Female
df2 = df[df['Gender']=='0']
cnt_female = df2.count
print(cnt_female)
# Out:
# <bound method DataFrame.count of      Individual  Attrition Age BusinessTravel DailyRate Department  \
# 2           Ind2        No  49              2       279          2
# 3           Ind3       Yes  37              1      1373          2
# 5           Ind5        No  27              1       591          2
# 6           Ind6        No  32              2      1005          2
# 8           Ind8        No  30              1      1358          2
# 9           Ind9        No  38              2       216          2
# 10         Ind10        No  36              1      1299          2
# 11         Ind11        No  35              1       809          2
# 13         Ind13        No  31              1       670          2
# 14         Ind14        No  34              1      1346          2
# 15         Ind15       Yes  28              1       103          2
# 17         Ind17        No  32              1       334          2
# ...

# %% [markdown]
# ### Find out the IQR for the column - Age
#
# *Hint: IQR - Interquartile range = 75th percentile - 25th percentile*

# %%
age1 = df.iloc[0:10, 2]
age1.quantile(q=0.75) - age1.quantile(q=0.25)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-3608eb6077e0> in <module>()
#       1 age1 = df.iloc[0:10, 2]
# ----> 2 age1.quantile(q=0.75) - age1.quantile(q=0.25)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/series.py in quantile(self, q, interpolation)
#    1876         self._check_percentile(q)
#    1877
# -> 1878         result = self._data.quantile(qs=q, interpolation=interpolation)
#    1879
#    1880         if is_list_like(q):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in quantile(self, **kwargs)
#    3688
#    3689     def quantile(self, **kwargs):
# -> 3690         return self.reduction('quantile', **kwargs)
#    3691
#    3692     def setitem(self, **kwargs):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in reduction(self, f, axis, consolidate, transposed, **kwargs)
# ...

# %% [markdown]
# ### Find out the mean, median and variance for the column - DailyRate

# %%
pd.DataFrame([df.mean(), df.std(), df.var()], index=['Mean', 'Std. dev', 'Variance']
# Out:
#   File "<ipython-input-27-3e5aa8774a54>", line 1
#     pd.DataFrame([df.mean(), df.std(), df.var()], index=['Mean', 'Std. dev', 'Variance']
#                                                                                         ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# ### Plot the attrition column (Since it is a categorical variable, chose the plot accordingly)

# %% [markdown]
# ### Plot Total working years using matplotlib plot function
